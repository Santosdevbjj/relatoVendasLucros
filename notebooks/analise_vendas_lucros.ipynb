# %% [markdown]
# <a href="https://colab.research.google.com/github/Santosdevbjj/relatoVendasLucros/blob/main/notebooks/analise_vendas_lucros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
---

# 📂 **/notebooks/analise_vendas_lucros.ipynb**
```python
# ---
# Análise de Vendas e Lucros — Sérgio Santos
# ---

import pandas as pd
import plotly.express as px

# === Carregar dados tratados ===
df = pd.read_csv("../data/vendas_tratadas.csv")

# === Resumo estatístico ===
display(df.describe())

# === Receita total e lucro médio ===
receita_total = df["Receita"].sum()
lucro_total = df["Lucro"].sum()
margem_media = (df["Lucro"] / df["Receita"]).mean()

print(f"Receita Total: R$ {receita_total:,.2f}")
print(f"Lucro Total: R$ {lucro_total:,.2f}")
print(f"Margem Média: {margem_media:.2%}")

# === Gráfico de área: receita por data ===
fig = px.area(df, x="Data", y="Receita", color="Nome_Regiao", title="Receita por Região ao Longo do Tempo")
fig.show()

# === Gráfico de barras: lucro por categoria ===
fig2 = px.bar(df.groupby("Categoria", as_index=False)["Lucro"].sum(),
              x="Categoria", y="Lucro", color="Categoria", title="Lucro por Categoria de Produto")
fig2.show()

# === Tabela resumo ===
resumo = df.groupby("Nome_Regiao")[["Receita", "Lucro"]].sum().reset_index()
display(resumo)
